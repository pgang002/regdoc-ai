# %% [markdown]
# # Day 7: PII/CCI detection and permanent redaction
# This notebook runs the same repository scripts and actual project data used for the measured Day 7 benchmark.

# %%
from pathlib import Path
import os, sys
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks': PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
print(PROJECT_ROOT)

# %% [markdown]
# ## Run the measured policy benchmark and create true redacted PDFs

# %%
# !python scripts/evaluate_redaction.py
# !python scripts/create_redaction_figures.py

# %%
import pandas as pd
pd.read_csv('results/redaction_benchmark/summary_overall.csv')

# %% [markdown]
# ## Optional statistical spaCy model
# The measured local run uses a generic EntityRuler because no statistical English model was downloaded. Run the following only in an environment with internet access, then implement/benchmark the model adapter separately. Do not overwrite the measured EntityRuler results.

# %%
# !python -m spacy download en_core_web_sm
# import spacy
# nlp = spacy.load('en_core_web_sm')
# [(ent.text, ent.label_) for ent in nlp('Omar Rahman, MD') .ents]

# %% [markdown]
# ## Inspect audit-safe output

# %%
import json
audit = json.load(open('results/redaction_benchmark/audit/FDA_1572_NCT04796896.json'))
audit['entities'][:3]

# %%
from IPython.display import Image, display
display(Image(filename='results/redaction_benchmark/figures/redaction_before_after.png'))
