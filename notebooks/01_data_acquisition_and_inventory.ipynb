# %% [markdown]
# # RegDocAI: actual-data acquisition and inventory
# This notebook runs the source acquisition, provenance, PDF inspection, rendering, and first OCR baseline.

# %%
# !python ../scripts/download_fda_forms.py
# !python ../scripts/build_data_manifest.py
# !python ../scripts/inspect_fda_forms.py

# %%
# !python ../scripts/render_fda_forms.py --dpi 150
# !python ../scripts/run_tesseract_baseline.py --modes raw clahe --psm 6

# %%
import pandas as pd
pd.read_csv('../results/tesseract_baseline/summary.csv')

# %% [markdown]
# ## Live API pull
# Run this cell in Colab or a local environment with internet access to retrieve current public ClinicalTrials.gov records.

# %%
# !python ../scripts/fetch_clinicaltrials.py --mode seed
# !python ../scripts/build_clinical_tables.py
